# %% [markdown]
# # Preparing Catergorical Variables
# - Columns -> Variables/Features
# - Rows -> Samples

# %% [markdown]
# ###  Step 1. Import Dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create a dataframe from the following dataset
# Explain what happens when this code runs.

# %%
data = pd.DataFrame( 
                    {
                        'Name':['Sizwe','Fatima',np.nan,'Margret','Samson','Miyelani','Neo','Darel'], 
                        'Age':[29,22,37,45,54,np.nan,12,32],
                        'Gender':['Male','Female','Female','Female','Male','Female','Male','Male'],
                        # 'MaritalStatus':['Single','Married',np.nan,'Divorced','Married','Married','Single','Divorced'],
                        'MaritalStatus':['Single','Married','Divorced','Divorced','Married','Married','Single','Divorced'],
                        'Employed':[True,True,False,False,True,False,True,False]    
                    })

# %%
data
# Out:
#        Name   Age  Gender MaritalStatus  Employed
# 0     Sizwe  29.0    Male        Single      True
# 1    Fatima  22.0  Female       Married      True
# 2       NaN  37.0  Female      Divorced     False
# 3   Margret  45.0  Female      Divorced     False
# 4    Samson  54.0    Male       Married      True
# 5  Miyelani   NaN  Female       Married     False
# 6       Neo  12.0    Male        Single      True
# 7     Darel  32.0    Male      Divorced     False

# %% [markdown]
# ###  Step 4. Identify and list all catergorical Variables

# %%
data[['Gender','MaritalStatus','Employed']]
# Out:
#    Gender MaritalStatus  Employed
# 0    Male        Single      True
# 1  Female       Married      True
# 2  Female      Divorced     False
# 3  Female      Divorced     False
# 4    Male       Married      True
# 5  Female       Married     False
# 6    Male        Single      True
# 7    Male      Divorced     False

# %% [markdown]
# ### Step 5. Manually prepare the Gender, MaritalStatus and Employed Variables/Columns

# %%
data_prepared = pd.DataFrame( {
                             'Name':['Sizwe','Fatima','Margret','Samson','Miyelani','Neo','Darel'], 
                              'Age':[29,22,37,45,54,12,32],
                              'Gender_Female':[0,1,1,1,1,0,0],
                              'Gender_Male':[1,0,0,0,0,1,1],
                              'Single':[1,0,0,0,0,1,0],
                              'Married':[0,1,0,1,1,0,0],
                              'Divorced':[0,0,1,0,0,0,1],
                              'Unemployed':[0,0,1,0,1,0,1],
                              'Employed':[1,1,0,1,0,1,0]
})

# %%
data_prepared
# Out:
#        Name  Age  Gender_Female  Gender_Male  Single  Married  Divorced  \
# 0     Sizwe   29              0            1       1        0         0
# 1    Fatima   22              1            0       0        1         0
# 2   Margret   37              1            0       0        0         1
# 3    Samson   45              1            0       0        1         0
# 4  Miyelani   54              1            0       0        1         0
# 5       Neo   12              0            1       1        0         0
# 6     Darel   32              0            1       0        0         1
#
#    Unemployed  Employed
# 0           0         1
# 1           0         1
# 2           1         0
# 3           0         1
# 4           1         0
# 5           0         1
# 6           1         0

# %% [markdown]
# # Fix Catergorical Variables using Panda's Get Dummies function
# ##### Referece: [Get Dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)

# %% [markdown]
# ### Step 1. Isolate catergorical variables from all non catergoriacal variables(Age and Name)

# %%
# Separate non catergorical  
data_non_catergorical = data[['Name','Age']]
data_non_catergorical
# Out:
#        Name   Age
# 0     Sizwe  29.0
# 1    Fatima  22.0
# 2       NaN  37.0
# 3   Margret  45.0
# 4    Samson  54.0
# 5  Miyelani   NaN
# 6       Neo  12.0
# 7     Darel  32.0

# %% [markdown]
# ### Stept 2. Use pandas's get dummies function to automatically prepare catergoriacal variables

# %%
data_prepared_dummies = pd.get_dummies(data.loc[:,'Gender':'Employed'])
data_prepared_dummies
# Out:
#    Employed  Gender_Female  Gender_Male  MaritalStatus_Divorced  \
# 0      True          False         True                   False
# 1      True           True        False                   False
# 2     False           True        False                    True
# 3     False           True        False                    True
# 4      True          False         True                   False
# 5     False           True        False                   False
# 6      True          False         True                   False
# 7     False          False         True                    True
#
#    MaritalStatus_Married  MaritalStatus_Single
# 0                  False                  True
# 1                   True                 False
# 2                  False                 False
# 3                  False                 False
# 4                   True                 False
# 5                   True                 False
# 6                  False                  True
# 7                  False                 False

# %% [markdown]
# ### Step 7. Merge final result

# %%
df = data_non_catergorical
df


df[['Employed','Gender_Female','Gender_Male','MaritalStatus_Divorced','MaritalStatus_Married','MaritalStatus_Single']] = data_prepared_dummies
df
# Out:
#        Name   Age  Employed  Gender_Female  Gender_Male  \
# 0     Sizwe  29.0      True          False         True
# 1    Fatima  22.0      True           True        False
# 2       NaN  37.0     False           True        False
# 3   Margret  45.0     False           True        False
# 4    Samson  54.0      True          False         True
# 5  Miyelani   NaN     False           True        False
# 6       Neo  12.0      True          False         True
# 7     Darel  32.0     False          False         True
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 0                   False                  False                  True
# 1                   False                   True                 False
# 2                    True                  False                 False
# 3                    True                  False                 False
# 4                   False                   True                 False
# 5                   False                   True                 False
# 6                   False                  False                  True
# 7                    True                  False                 False

# %% [markdown]
# # Section  - Panda's Get Dummies Excercise 2
# #### Step 1 . Create a dataframe

# %%
df = pd.DataFrame(
                    {
                     'Group': ['a', 'b', 'a'],
                     'Symbol': ['b', 'a', 'c'],
                     'Position': [1, 2, 3],
                     'Diet':['Vegeterian','MeatEater','AmasiAndPuthu']  
                    })

df
# Out:
#   Group Symbol  Position           Diet
# 0     a      b         1     Vegeterian
# 1     b      a         2      MeatEater
# 2     a      c         3  AmasiAndPuthu

# %% [markdown]
# ##  Step 2. Identify and list all catergorical Variables

# %%
df[['Group','Symbol','Position','Diet']]
# Out:
#   Group Symbol  Position           Diet
# 0     a      b         1     Vegeterian
# 1     b      a         2      MeatEater
# 2     a      c         3  AmasiAndPuthu

# %% [markdown]
# ##  Step 3. Use pandas's get dummies function to automatically prepare catergoriacal variables

# %%
# ## After 
pd.get_dummies(df)
# Out:
#    Position  Group_a  Group_b  Symbol_a  Symbol_b  Symbol_c  \
# 0         1     True    False     False      True     False
# 1         2    False     True      True     False     False
# 2         3     True    False     False     False      True
#
#    Diet_AmasiAndPuthu  Diet_MeatEater  Diet_Vegeterian
# 0               False           False             True
# 1               False            True            False
# 2                True           False            False

# %% [markdown]
# #  Trasform Catergorical data using SKLearn
# - from sklearn.preprocessing
# - use LabelEncoder
# Reference - [SKLEARN](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)

# %% [markdown]
# ### Question: What does the following code do?
#
# Explain what happens when this code runs.

# %% [markdown]
# ### Step 1 . Import Dependencies

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Step 2. Create instance of LabelEncoder

# %%
## Create new LabelEncoder 
encoder = LabelEncoder()

# %% [markdown]
# ### Step 3. Create a copy of you original dataset

# %%
data_copy = data.copy()
data_copy.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'MaritalStatus', 'Employed'], dtype='object')

# %% [markdown]
# ### Step 4. Isolate columns to fit int the Encoder/ columns that you want to prepare

# %%
## Train/Fit the Encoder
data_copy['Gender'] = encoder.fit_transform(data_copy['Gender'])
data_copy['MaritalStatus'] = encoder.fit_transform(data_copy['MaritalStatus'])
data_copy['Employed'] = encoder.fit_transform(data_copy['Employed'])
data_copy
# Out:
#        Name   Age  Gender  MaritalStatus  Employed
# 0     Sizwe  29.0       1              2         1
# 1    Fatima  22.0       0              1         1
# 2       NaN  37.0       0              0         0
# 3   Margret  45.0       0              0         0
# 4    Samson  54.0       1              1         1
# 5  Miyelani   NaN       0              1         0
# 6       Neo  12.0       1              2         1
# 7     Darel  32.0       1              0         0
